# %% [markdown]
# <a href="https://colab.research.google.com/github/pathumma-55/python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N=10
k=5

R=N
c=1

while c != 0:
    d = int(input("no of candies:"))

    if d > R :
      print("INVALID INPUT")
      break

    R = R - d
    print("no of candies sold:",d)

    if R <= k:
        R = N

    print("no of candies available:", R)

    c = int(input("enter 1 to continue, 0 to stop: "))
# Out:
# no of candies:3
# no of candies sold: 3
# no of candies available: 7
# enter 1 to continue, 0 to stop: 1
# no of candies:6
# no of candies sold: 6
# no of candies available: 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1590/1734705479.py in <cell line: 0>()
#      20     print("no of candies available:", R)
#      21
# ---> 22     c = int(input("enter 1 to continue, 0 to stop: "))
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...
